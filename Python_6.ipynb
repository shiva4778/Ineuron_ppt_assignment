# %%
import pandas as pd
import csv
import numpy as np
from urllib.request import urlopen
import json
url="https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json" 
raw_data=urlopen(url).read() # Downloading the data
json=json.loads(raw_data)

# %%
# Checking the column
record=(json["pokemon"])

# %%
field_name=['id', 'num', 'name', 'img', 'type', 'height', 'weight', 'candy',
       'candy_count', 'egg', 'spawn_chance', 'avg_spawns', 'spawn_time',
       'multipliers', 'weaknesses', 'prev_evolution', 'next_evolution']

# %%
# Saving the file
with open('output.csv', 'w', newline='') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=field_name)
    writer.writeheader()
    writer.writerows(record)

# %%
# Reading the file
df1=pd.read_csv('output.csv')

# %%
# Changing the Pokeman height data type to float 
def height1(i):
  a=i.split()[0]
  return float(a)

df1['height']=df1['height'].apply(height1)

# Changing the Pokémon weight to float
def weight1(i):
  a=i.split()[0]
  return float(a)
df1['weight']=df1['weight'].apply(weight1)

# %%
# candy_count: the amount of candies required to evolve int

def candy_count(i):
    try:
        return int(i)
    except ValueError:
        return 0

df1['candy_count'] = df1['candy_count'].apply(candy_count)

# %%
# : Number of kilometers to travel to hatch the egg - float
def egg1(i):
  a=i.split()[0]
  try:
      return float(a)
  except ValueError:
      return 0
df1["egg"]=df1["egg"].apply(egg1)

# %%
# avg_spawns: Number of this pokemon on 10.000 spawns (NEW) - int
def avg_spawn1(i):
  try:
    a=str(i).split(':')
    
    if len(a)==2:
    
      return float(a[0]+'.'+a[1])
    else:
      return float(a[0])
    


  except ValueError:
    return 0

df1['avg_spawns']=df1["avg_spawns"].apply(avg_spawn1)

# %%
# avg_spawns: Number of this pokemon on 10.000 spawns (NEW) - int
def convert_multipliers(multipliers):
    try:
        evaluated_obj = eval(multipliers)
        if isinstance(evaluated_obj, list):
            return evaluated_obj
    except (ValueError, TypeError):
        pass
    return np.nan

df1['multipliers'] = df1['multipliers'].apply(convert_multipliers)

# %%
#Percentage of spawn chance (NEW) - float
df1['spawn_chance']=df1['spawn_chance']/100

# %%
# avg_spawns: Number of this pokemon on 10.000 spawns (NEW) - int
df1['avg_spawns']=df1['avg_spawns']*10
df1['avg_spawns']=df1['avg_spawns'].astype(int,errors='ignore')

# Creating a new datetime column with combined minute and second
df1['spawn_time'] = df1['spawn_time'].fillna('00:00')

df1['spawn_time'] = pd.to_datetime(df1['spawn_time'], format="%M:%S")

# %%
# Saving the csv  file to xlsx file
df2=df1
excel_file_name='pokeman.xlsx'
df1.to_excel(excel_file_name, index=False)

# %%
df1.head()
# Out:
#    id  num        name                                               img  \
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height  weight             candy  candy_count  egg  \
# 0  ['Grass', 'Poison']    0.71     6.9   Bulbasaur Candy           25  2.0
# 1  ['Grass', 'Poison']    0.99    13.0   Bulbasaur Candy          100  0.0
# 2  ['Grass', 'Poison']    2.01   100.0   Bulbasaur Candy            0  0.0
# 3             ['Fire']    0.61     8.5  Charmander Candy           25  2.0
# 4             ['Fire']    1.09    19.0  Charmander Candy          100  0.0
#
#    spawn_chance  avg_spawns          spawn_time multipliers  \
# 0       0.00690         690 1900-01-01 00:20:00      [1.58]
# 1       0.00042          42 1900-01-01 00:07:00  [1.2, 1.6]
# 2       0.00017          17 1900-01-01 00:11:30         NaN
# 3       0.00253         253 1900-01-01 00:08:45      [1.65]
# 4       0.00012          12 1900-01-01 00:19:00      [1.79]
#
#                              weaknesses  \
# 0  ['Fire', 'Ice', 'Flying', 'Psychic']
# 1  ['Fire', 'Ice', 'Flying', 'Psychic']
# 2  ['Fire', 'Ice', 'Flying', 'Psychic']
# 3           ['Water', 'Ground', 'Rock']
# 4           ['Water', 'Ground', 'Rock']
#
#                                       prev_evolution  \
# 0                                                NaN
# 1              [{'num': '001', 'name': 'Bulbasaur'}]
# 2  [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3                                                NaN
# 4             [{'num': '004', 'name': 'Charmander'}]
#
#                                       next_evolution
# 0  [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...
# 1               [{'num': '003', 'name': 'Venusaur'}]
# 2                                                NaN
# 3  [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4              [{'num': '006', 'name': 'Charizard'}]

# %%
df1.dtypes
# Out:
# id                         int64
# num                        int64
# name                      object
# img                       object
# type                      object
# height                   float64
# weight                   float64
# candy                     object
# candy_count                int64
# egg                      float64
# spawn_chance             float64
# avg_spawns                 int64
# spawn_time        datetime64[ns]
# multipliers               object
# weaknesses                object
# prev_evolution            object
# next_evolution            object
# dtype: object

# %%
# Get all Pokemons whose spawn rate is less than 5%
df2[df2['spawn_chance']<0.05]
# Out:
#       id  num        name                                               img  \
# 0      1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3      4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# ..   ...  ...         ...                                               ...
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                      type  height  weight             candy  candy_count  \
# 0     ['Grass', 'Poison']    0.71     6.9   Bulbasaur Candy           25
# 1     ['Grass', 'Poison']    0.99    13.0   Bulbasaur Candy          100
# 2     ['Grass', 'Poison']    2.01   100.0   Bulbasaur Candy            0
# 3                ['Fire']    0.61     8.5  Charmander Candy           25
# 4                ['Fire']    1.09    19.0  Charmander Candy          100
# ..                    ...     ...     ...               ...          ...
# 146            ['Dragon']    1.80     3.3     Dratini Candy           25
# 147            ['Dragon']    3.99    16.5     Dratini Candy          100
# 148  ['Dragon', 'Flying']    2.21   210.0     Dratini Candy            0
# 149           ['Psychic']    2.01   122.0              None            0
# 150           ['Psychic']    0.41     4.0              None            0
#
#       egg  spawn_chance  avg_spawns          spawn_time   multipliers  \
# 0     2.0      0.006900         690 1900-01-01 00:20:00        [1.58]
# 1     0.0      0.000420          42 1900-01-01 00:07:00    [1.2, 1.6]
# 2     0.0      0.000170          17 1900-01-01 00:11:30           NaN
# 3     2.0      0.002530         253 1900-01-01 00:08:45        [1.65]
# 4     0.0      0.000120          12 1900-01-01 00:19:00        [1.79]
# ..    ...           ...         ...                 ...           ...
# 146  10.0      0.003000         300 1900-01-01 00:06:41  [1.83, 1.84]
# 147   0.0      0.000200          20 1900-01-01 00:11:57        [2.05]
# 148   0.0      0.000011           1 1900-01-01 00:23:38           NaN
# 149   0.0      0.000000           0 1900-01-01 00:00:00           NaN
# 150   0.0      0.000000           0 1900-01-01 00:00:00           NaN
#
#                                weaknesses  \
# 0    ['Fire', 'Ice', 'Flying', 'Psychic']
# 1    ['Fire', 'Ice', 'Flying', 'Psychic']
# 2    ['Fire', 'Ice', 'Flying', 'Psychic']
# 3             ['Water', 'Ground', 'Rock']
# 4             ['Water', 'Ground', 'Rock']
# ..                                    ...
# 146            ['Ice', 'Dragon', 'Fairy']
# 147            ['Ice', 'Dragon', 'Fairy']
# 148    ['Ice', 'Rock', 'Dragon', 'Fairy']
# 149              ['Bug', 'Ghost', 'Dark']
# 150              ['Bug', 'Ghost', 'Dark']
#
#                                         prev_evolution  \
# 0                                                  NaN
# 1                [{'num': '001', 'name': 'Bulbasaur'}]
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3                                                  NaN
# 4               [{'num': '004', 'name': 'Charmander'}]
# ..                                                 ...
# 146                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...
# 149                                                NaN
# 150                                                NaN
#
#                                         next_evolution
# 0    [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...
# 1                 [{'num': '003', 'name': 'Venusaur'}]
# 2                                                  NaN
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4                [{'num': '006', 'name': 'Charizard'}]
# ..                                                 ...
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...
# 147              [{'num': '149', 'name': 'Dragonite'}]
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
#
# [147 rows x 17 columns]

# %%
# Get all Pokemons that have less than 4 weaknesses
def len_weakness(i):
  
  return len(eval(i))

df2['weakness_length']=df2['weaknesses'].apply(len_weakness)
df2[df2['weakness_length']<4]
# Out:
#       id  num        name                                               img  \
# 3      4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6      7    7    Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                    type  height  weight             candy  candy_count   egg  \
# 3              ['Fire']    0.61     8.5  Charmander Candy           25   2.0
# 4              ['Fire']    1.09    19.0  Charmander Candy          100   0.0
# 5    ['Fire', 'Flying']    1.70    90.5  Charmander Candy            0   0.0
# 6             ['Water']    0.51     9.0    Squirtle Candy           25   2.0
# 7             ['Water']    0.99    22.5    Squirtle Candy          100   0.0
# ..                  ...     ...     ...               ...          ...   ...
# 145  ['Fire', 'Flying']    2.01    60.0              None            0   0.0
# 146          ['Dragon']    1.80     3.3     Dratini Candy           25  10.0
# 147          ['Dragon']    3.99    16.5     Dratini Candy          100   0.0
# 149         ['Psychic']    2.01   122.0              None            0   0.0
# 150         ['Psychic']    0.41     4.0              None            0   0.0
#
#      spawn_chance  avg_spawns          spawn_time   multipliers  \
# 3        0.002530         253 1900-01-01 00:08:45        [1.65]
# 4        0.000120          12 1900-01-01 00:19:00        [1.79]
# 5        0.000031           3 1900-01-01 00:13:34           NaN
# 6        0.005800         580 1900-01-01 00:04:25         [2.1]
# 7        0.000340          34 1900-01-01 00:07:02         [1.4]
# ..            ...         ...                 ...           ...
# 145      0.000000           0 1900-01-01 00:00:00           NaN
# 146      0.003000         300 1900-01-01 00:06:41  [1.83, 1.84]
# 147      0.000200          20 1900-01-01 00:11:57        [2.05]
# 149      0.000000           0 1900-01-01 00:00:00           NaN
# 150      0.000000           0 1900-01-01 00:00:00           NaN
#
#                         weaknesses  \
# 3      ['Water', 'Ground', 'Rock']
# 4      ['Water', 'Ground', 'Rock']
# 5    ['Water', 'Electric', 'Rock']
# 6            ['Electric', 'Grass']
# 7            ['Electric', 'Grass']
# ..                             ...
# 145  ['Water', 'Electric', 'Rock']
# 146     ['Ice', 'Dragon', 'Fairy']
# 147     ['Ice', 'Dragon', 'Fairy']
# 149       ['Bug', 'Ghost', 'Dark']
# 150       ['Bug', 'Ghost', 'Dark']
#
#                                         prev_evolution  \
# 3                                                  NaN
# 4               [{'num': '004', 'name': 'Charmander'}]
# 5    [{'num': '004', 'name': 'Charmander'}, {'num':...
# 6                                                  NaN
# 7                 [{'num': '007', 'name': 'Squirtle'}]
# ..                                                 ...
# 145                                                NaN
# 146                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 149                                                NaN
# 150                                                NaN
#
#                                         next_evolution  weakness_length
# 3    [{'num': '005', 'name': 'Charmeleon'}, {'num':...                3
# 4                [{'num': '006', 'name': 'Charizard'}]                3
# 5                                                  NaN                3
# 6    [{'num': '008', 'name': 'Wartortle'}, {'num': ...                2
# 7                [{'num': '009', 'name': 'Blastoise'}]                2
# ..                                                 ...              ...
# 145                                                NaN                3
# 146  [{'num': '148', 'name': 'Dragonair'}, {'num': ...                3
# 147              [{'num': '149', 'name': 'Dragonite'}]                3
# 149                                                NaN                3
# 150                                                NaN                3
#
# [102 rows x 18 columns]

# %%
# Get all Pokemons that do not have more than 2 evolutions

def evolution_length(i):
    try:
        if pd.isnull(i):
            return 0
        else:
            return len(eval(i))
    except ValueError:
        raise np.nan

df2['evolution_length'] = df2['next_evolution'].apply(evolution_length)
df2[df2['evolution_length']<2]
# Out:
#       id  num        name                                               img  \
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                      type  height  weight             candy  candy_count  egg  \
# 1     ['Grass', 'Poison']    0.99    13.0   Bulbasaur Candy          100  0.0
# 2     ['Grass', 'Poison']    2.01   100.0   Bulbasaur Candy            0  0.0
# 4                ['Fire']    1.09    19.0  Charmander Candy          100  0.0
# 5      ['Fire', 'Flying']    1.70    90.5  Charmander Candy            0  0.0
# 7               ['Water']    0.99    22.5    Squirtle Candy          100  0.0
# ..                    ...     ...     ...               ...          ...  ...
# 145    ['Fire', 'Flying']    2.01    60.0              None            0  0.0
# 147            ['Dragon']    3.99    16.5     Dratini Candy          100  0.0
# 148  ['Dragon', 'Flying']    2.21   210.0     Dratini Candy            0  0.0
# 149           ['Psychic']    2.01   122.0              None            0  0.0
# 150           ['Psychic']    0.41     4.0              None            0  0.0
#
#      spawn_chance  avg_spawns          spawn_time multipliers  \
# 1        0.000420          42 1900-01-01 00:07:00  [1.2, 1.6]
# 2        0.000170          17 1900-01-01 00:11:30         NaN
# 4        0.000120          12 1900-01-01 00:19:00      [1.79]
# 5        0.000031           3 1900-01-01 00:13:34         NaN
# 7        0.000340          34 1900-01-01 00:07:02       [1.4]
# ..            ...         ...                 ...         ...
# 145      0.000000           0 1900-01-01 00:00:00         NaN
# 147      0.000200          20 1900-01-01 00:11:57      [2.05]
# 148      0.000011           1 1900-01-01 00:23:38         NaN
# 149      0.000000           0 1900-01-01 00:00:00         NaN
# 150      0.000000           0 1900-01-01 00:00:00         NaN
#
#                                weaknesses  \
# 1    ['Fire', 'Ice', 'Flying', 'Psychic']
# 2    ['Fire', 'Ice', 'Flying', 'Psychic']
# 4             ['Water', 'Ground', 'Rock']
# 5           ['Water', 'Electric', 'Rock']
# 7                   ['Electric', 'Grass']
# ..                                    ...
# 145         ['Water', 'Electric', 'Rock']
# 147            ['Ice', 'Dragon', 'Fairy']
# 148    ['Ice', 'Rock', 'Dragon', 'Fairy']
# 149              ['Bug', 'Ghost', 'Dark']
# 150              ['Bug', 'Ghost', 'Dark']
#
#                                         prev_evolution  \
# 1                [{'num': '001', 'name': 'Bulbasaur'}]
# 2    [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 4               [{'num': '004', 'name': 'Charmander'}]
# 5    [{'num': '004', 'name': 'Charmander'}, {'num':...
# 7                 [{'num': '007', 'name': 'Squirtle'}]
# ..                                                 ...
# 145                                                NaN
# 147                [{'num': '147', 'name': 'Dratini'}]
# 148  [{'num': '147', 'name': 'Dratini'}, {'num': '1...
# 149                                                NaN
# 150                                                NaN
#
#                             next_evolution  weakness_length  evolution_length
# 1     [{'num': '003', 'name': 'Venusaur'}]                4                 1
# 2                                      NaN                4                 0
# 4    [{'num': '006', 'name': 'Charizard'}]                3                 1
# 5                                      NaN                3                 0
# 7    [{'num': '009', 'name': 'Blastoise'}]                2                 1
# ..                                     ...              ...               ...
# 145                                    NaN                3                 0
# 147  [{'num': '149', 'name': 'Dragonite'}]                3                 1
# 148                                    NaN                4                 0
# 149                                    NaN                3                 0
# 150                                    NaN                3                 0
#
# [134 rows x 19 columns]

# %%
# Assuming we have a DataFrame named 'df2' containing Pokémon data

# Extracting minutes and seconds from 'spawn_time' column and convert to seconds
df2['spawn_seconds'] = df2['spawn_time'].apply(lambda x: x.minute * 60 + x.second)

# Filtering the DataFrame to get Pokémon with spawn time less than 300 seconds
spawn_time_less_than_300 = df2[df2['spawn_seconds'] < 300]

# Print the resulting Pokémon
spawn_time_less_than_300.head()
# Out:
#     id  num       name                                               img  \
# 6    7    7   Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 8    9    9  Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 10  11   11    Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 12  13   13     Weedle  http://www.serebii.net/pokemongo/pokemon/013.png
# 13  14   14     Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
#
#                  type  height  weight           candy  candy_count  egg  \
# 6           ['Water']    0.51     9.0  Squirtle Candy           25  2.0
# 8           ['Water']    1.60    85.5  Squirtle Candy            0  0.0
# 10            ['Bug']    0.71     9.9  Caterpie Candy           50  0.0
# 12  ['Bug', 'Poison']    0.30     3.2    Weedle Candy           12  2.0
# 13  ['Bug', 'Poison']    0.61    10.0    Weedle Candy           50  0.0
#
#     spawn_chance  avg_spawns          spawn_time   multipliers  \
# 6       0.005800         580 1900-01-01 00:04:25         [2.1]
# 8       0.000067           6 1900-01-01 00:00:06           NaN
# 10      0.001870         187 1900-01-01 00:02:11  [3.55, 3.79]
# 12      0.071200        7120 1900-01-01 00:02:21  [1.01, 1.09]
# 13      0.004400         440 1900-01-01 00:02:30  [3.01, 3.41]
#
#                                weaknesses  \
# 6                   ['Electric', 'Grass']
# 8                   ['Electric', 'Grass']
# 10             ['Fire', 'Flying', 'Rock']
# 12  ['Fire', 'Flying', 'Psychic', 'Rock']
# 13  ['Fire', 'Flying', 'Psychic', 'Rock']
#
#                                        prev_evolution  \
# 6                                                 NaN
# 8   [{'num': '007', 'name': 'Squirtle'}, {'num': '...
# 10               [{'num': '010', 'name': 'Caterpie'}]
# 12                                                NaN
# 13                 [{'num': '013', 'name': 'Weedle'}]
#
#                                        next_evolution  weakness_length  \
# 6   [{'num': '008', 'name': 'Wartortle'}, {'num': ...                2
# 8                                                 NaN                2
# 10             [{'num': '012', 'name': 'Butterfree'}]                3
# 12  [{'num': '014', 'name': 'Kakuna'}, {'num': '01...                4
# 13               [{'num': '015', 'name': 'Beedrill'}]                4
#
#     evolution_length  spawn_seconds
# 6                  2            265
# 8                  0              6
# 10                 1            131
# 12                 2            141
# 13                 1            150
